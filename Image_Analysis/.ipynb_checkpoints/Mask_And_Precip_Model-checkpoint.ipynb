# %% [markdown]
# # Working with new masks (if the masks and center.csv files are already saved to the local directory you can start from this point if not make them with the Mask Notebook)

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
centers_back = pd.read_csv('Centers_back.csv')
CB = centers_back.drop('Unnamed: 0',axis=1)
CB_array = CB.to_numpy()
centers_back = [(CB_array[0][i],CB_array[1][i]) for i in range(len(CB_array[0]))]

# %%
centers2 = pd.read_csv('Centers_front.csv')
CB = centers2.drop('Unnamed: 0',axis=1)
CB_array = CB.to_numpy()
centers = [(CB_array[0][i],CB_array[1][i]) for i in range(len(CB_array[0]))]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.color import rgb2gray
import os 

fname = 'Plate_Image.jpg'
fname2 = 'Plate_back_image.jpg'
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(12, 8))

mask = rgb2gray(mpimg.imread(fname))
ax[0].imshow(mask, cmap='gray')

mask2 = rgb2gray(mpimg.imread(fname2))
ax[1].imshow(mask2, cmap='gray')

# %%
from skimage.measure import label, regionprops
from skimage.morphology import opening, disk

smask = opening(mask, disk(10)) # this seems to be needed to remove some noise
smask2 = opening(mask2,disk(10))
label_image, num = label(smask > 0, return_num=True)
label_image2, num2 = label(smask2 > 0 , return_num=True)
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(12, 8))
ax[0].imshow(label_image)
ax[1].imshow(label_image2)
(num,num2)

# %% [markdown]
# ## Working with the labeled images

# %%
import numpy as np

regions = regionprops(label_image)
print(len(regions))
centroids = [(i, region.centroid) for i, region in enumerate(regions)]

# Sort the centroids by y
centroids = sorted(centroids, key=lambda x: x[1][0])

rows = np.split(np.array(centroids), 9)
# we sort each row on x
rows = [sorted(row, key=lambda x: x[1][1]) for row in rows]

wells = np.concatenate(rows)
indices = [x[0] for x in wells]
ordered_regions = [regions[i] for i in indices];

plt.figure(figsize=(18, 16))
plt.imshow(mask, cmap='gray')
for n, region in enumerate(ordered_regions):
    j, i = region.centroid
    plt.plot(i, j, 'ro', ms=2) # we plot these in the opposite order we read them.
    plt.text(i, j, f'{n}', ha='center')

# %%
import numpy as np

regions2 = regionprops(label_image2)

centroids2 = [(i, region2.centroid) for i, region2 in enumerate(regions2)]

# Sort the centroids by y
centroids2 = sorted(centroids2, key=lambda x: x[1][0])

rows2 = np.split(np.array(centroids2), 9)
# we sort each row on x
rows2 = [sorted(row, key=lambda x: x[1][1]) for row in rows2]

wells2 = np.concatenate(rows2)
indices2 = [x[0] for x in wells2]
ordered_regions2 = [regions2[i] for i in indices2];
#print(indices2)
plt.figure(figsize=(18, 16))
plt.imshow(mask2, cmap='gray')
for n, region in enumerate(ordered_regions2):
    j, i = region.centroid
    plt.plot(i, j, 'ro', ms=2) # we plot these in the opposite order we read them.
    plt.text(i, j, f'{n}', ha='center')

# %% [markdown]
# ### This is just a helper function to store the sorted file names for each of the images in a given directory

# %%
dir_under, = !find . -type d | grep Under
dir_over, = !find . -type d | grep Over

# %%
import os 

def switch_dir(directory):
    """" Input "Over", "Under" or "Main" to switch the working directory to the desired location. 
    If you are not in one of the specified paths in the Image Analysis folder it will tell you. """

    
    if os.getcwd().endswith('/Image_Analysis'):
        if directory == 'Main':
            os.chdir('.')
        elif directory == 'Over':
            os.chdir(dir_over)
        elif directory == 'Under':
            os.chdir(dir_under)
        else:
            print('The only options are Main, Over, and Under')
    elif os.getcwd().endswith(dir_over.split('.')[-1]):
        if directory == 'Main':
            os.chdir('..')
        elif directory == 'Over':
            os.chdir('.')
        elif directory == 'Under':
            os.chdir('.'+ dir_under)
        else:
            print('The only options are Main, Over, and Under')
    elif os.getcwd().endswith(dir_under.split('.')[-1]):
        if directory == 'Main':
            os.chdir('..')
        elif directory == 'Over':
            os.chdir('.' + dir_over)
        elif directory == 'Under':
            os.chdir('.')
        else:
            print('The only options are Main, Over, and Under')
    else:
        print('You do not seem to be in a recognized directory')

# %%
switch_dir('Over')
def search_util(root='.'):
    """Recursively find all files in a directory.
    root - This is the directory you would like to find the files in, defaults to cwd""" 
    files = []
    for r, d, f in os.walk(root):
        for file in f:
            if os.path.join(r, file).endswith('.jpg'):
                files += [os.path.join(r, file)]
    return sorted(files)
Over = search_util()

# %%
switch_dir('Under')
Under = search_util()

# %%
print(len(Over),len(Under))
# Out:
# 122 122

# %%
import seaborn as sns

# %% [markdown]
# ## Building an interactive tool for visualizing changes in individual wells

# %% [markdown]
# Collecting the RGB values from the bottom image of the plate as well as the change in darkness values from the top image

# %%
Well_Num = [54,55] # Well numbers you want to visualize (you can locate the well numbers on the images displayed above)

# %%
import skimage
import time 
start = time.time()
if isinstance(Well_Num,list):
    Red = np.zeros((len(Well_Num),len(Under)))
    Green = np.zeros((len(Well_Num),len(Under)))
    Blue = np.zeros((len(Well_Num),len(Under)))
    H2 = np.zeros((len(Well_Num),len(Over)))
    Time = []
    counter = 0
    for j in range(len(Well_Num)):
        Region = ordered_regions[Well_Num[j]]
        Region2 = ordered_regions2[Well_Num[j]]
        for i in range(len(Under)):
            switch_dir('Under')
            plate = mpimg.imread(Under[i]).copy()
            mask2 = np.ones(shape=plate.shape[0:2], dtype="bool") # create the mask image
            R = 56 - 3 # Radius of circles
            #i = 1

            for coor in centers_back:
                x = int(coor[0])
                y = int(coor[1])
                rr, cc = skimage.draw.circle(y, x, radius=R, shape=plate.shape[0:2])
                mask2[rr, cc] = False

            # Apply the mask
            plate[mask2] = 0
            back = plate
            pixels = back[Region2.slice]
            Red[j,i] = np.max(pixels[:,:,0])
            Green[j,i] = np.max(pixels[:,:,1])
            Blue[j,i] = np.max(pixels[:,:,2])
            if j == 0:
                Time.append(counter)
                counter += 10


        for i in range(len(Over)):
            switch_dir('Over')
            plate = mpimg.imread(Over[i]).copy()
            mask2 = np.ones(shape=plate.shape[0:2], dtype="bool") # create the mask image
            R = 56 - 15 # Radius of circles


            for coor in centers:
                x = int(coor[0])
                y = int(coor[1])
                rr, cc = skimage.draw.circle(y, x, radius=R, shape=plate.shape[0:2])
                mask2[rr, cc] = False

            # Apply the mask
            plate[mask2] = 0
            front = plate
            pixels = front[Region.slice]####################
            if i == 0:
                base_line = np.mean(pixels)
            H2[j,i] = np.mean(pixels)/base_line
    
else:
    Red = []
    Green = []
    Blue = []
    Time = []
    counter = 0
    
    Region = ordered_regions[Well_Num]
    Region2 = ordered_regions2[Well_Num]
    for i in range(len(Under)):
        switch_dir('Under')
        
        plate = mpimg.imread(Under[i]).copy()
        mask2 = np.ones(shape=plate.shape[0:2], dtype="bool") # create the mask image
        R = 56 - 3 # Radius of circles
        i = 1

        for coor in centers_back:
            x = int(coor[0])
            y = int(coor[1])
            rr, cc = skimage.draw.circle(y, x, radius=R, shape=plate.shape[0:2])
            i = 2
            mask2[rr, cc] = False

        # Apply the mask
        plate[mask2] = 0
        back = plate
        pixels = back[Region2.slice]####################
        Red.append(np.max(pixels[:,:,0]))
        Green.append(np.max(pixels[:,:,1]))
        Blue.append(np.max(pixels[:,:,2]))
        Time.append(counter)
        counter += 10

    H2 = []

    for i in range(len(Over)):
        switch_dir('Over')
        plate = mpimg.imread(Over[i]).copy()
        mask2 = np.ones(shape=plate.shape[0:2], dtype="bool") # create the mask image
        R = 56 - 15 # Radius of circles


        for coor in centers:
            x = int(coor[0])
            y = int(coor[1])
            rr, cc = skimage.draw.circle(y, x, radius=R, shape=plate.shape[0:2])
            mask2[rr, cc] = False

        # Apply the mask
        plate[mask2] = 0
        front = plate
        pixels = front[Region.slice]
        if i == 0:
            base_line = np.mean(pixels)
        H2.append(np.mean(pixels)/base_line)

print(time.time()-start)
# Out:
# 109.74934530258179

# %% [markdown]
# **Below is the interactive tool the well number is inputed and then the graphs are built and the images can be scrolled through**

# %%
# !pwd
# Out:
# /home/ubuntu/Image_Analysis/AuPdAuPbWrr0728Over

# %%
import os
from IPython.display import Image, display
from IPython.html.widgets import interact
from skimage.color import rgb2gray
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import skimage 

def Plate_view(well_num,f1,f2,k):
    switch_dir('Over')
    front = rgb2gray(mpimg.imread(f1))
    image2 = front.copy() # Copying the original image of the plate

    mask = np.ones(shape=image2.shape[0:2], dtype="bool") # create the mask image
    R = 56 - 15 # Radius of circles
    i = 1
    
    for coor in centers:
        x = int(coor[0])
        y = int(coor[1])
        rr, cc = skimage.draw.circle(y, x, radius=R, shape=image2.shape[0:2])
        i = 2
        mask[rr, cc] = False

    # Apply the mask
    image2[mask] = 0
    front = image2
    switch_dir('Under')
    back = mpimg.imread(f2)
    image3 = back.copy() # Copying the original image of the plate

    mask2 = np.ones(shape=image3.shape[0:2], dtype="bool") # create the mask image
    R = 56 - 3 # Radius of circles
    i = 1

    for coor in centers_back:
        x = int(coor[0])
        y = int(coor[1])
        rr, cc = skimage.draw.circle(y, x, radius=R, shape=image3.shape[0:2])
        i = 2
        mask2[rr, cc] = False

    # Apply the mask
    image3[mask2] = 0
    back = image3
    if isinstance(well_num,list):
        sns.set_style("dark")
        fig, ax = plt.subplots(nrows=len(well_num),ncols=4,figsize=(13, 10))
        for i in range(len(well_num)):
            x1,y1,x2,y2 = ordered_regions[well_num[i]].bbox
            x12,y12,x22,y22 = ordered_regions2[well_num[i]].bbox

            pix = back[x12:x22,y12:y22]
            pix_front = front[x1:x2,y1:y2]
            
            ax[i,0].imshow(front[x1:x2,y1:y2], cmap='gray')
            ax[i,0].set_title(f'Front View for Well: {well_num[i]}')
            ax[i,2].imshow(back[x12:x22,y12:y22],cmap='gray')
            ax[i,2].set_title(f'Back View for Well: {well_num[i]}')
            ax[i,3].plot(Time,Red[i],'r--',Time,Green[i],'g--',Time,Blue[i],'b--',k*10,Red[i,k],'ko',k*10,Green[i,k],'ko',k*10,Blue[i,k],'ko')
            ax[i,3].set_title(f'Color Change for Well {well_num[i]}')
            ax[i,3].set_xlabel('Time (minutes)')
            
            ax[i,1].plot(Time,H2[i,:],'--',k*10,H2[i,k],'ko')
            ax[i,1].set_title(f'Change in Darkness for Well {well_num[i]}')
            ax[i,1].set_xlabel('Time (minutes)')
            ax[i,1].set_ylim([np.min(H2), np.max(H2)])
    else:
    
        x1,y1,x2,y2 = ordered_regions[well_num].bbox
        x12,y12,x22,y22 = ordered_regions2[well_num].bbox

        pix = back[x12:x22,y12:y22]
        pix_front = front[x1:x2,y1:y2]
        sns.set_style("dark")
        fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(12, 8))
        ax[0].imshow(front[x1:x2,y1:y2], cmap='gray')
        ax[0].set_title('Front View')
        ax[1].imshow(back[x12:x22,y12:y22],cmap='gray')
        ax[1].set_title('Back View')
        ax[2].plot(Time,Red,'r--',Time,Green,'g--',Time,Blue,'b--',k*10,Red[k],'ko',k*10,Green[k],'ko',k*10,Blue[k],'ko')
        ax[2].set_title('Color Change')
        ax[2].set_xlabel('Time (minutes)')
        ax[3].plot(Time,H2,'--',k*10,H2[k],'ko')
        ax[3].set_title('Change in Darkness')
        ax[3].set_xlabel('Time (minutes)')
        #ax[2].set_legend(['Red','Green','Blue'])
        
    print(f'Well number(s) {Well_Num}' + '\n' + f'Time = {k*10} minutes')

def loadimg(k):
    switch_dir('Over')
    f1 = Over[k]
    switch_dir('Under')
    f2 = Under[k]
    Plate_view(Well_Num,f1,f2,k)

interact(loadimg, k=(0, len(Over)-3))
# Out:
# interactive(children=(IntSlider(value=59, description='k', max=119), Output()), _dom_classes=('widget-interact…
# <function __main__.loadimg(k)>

# %% [markdown]
# # Detecting Precipitate

# %%
len(ordered_regions2)
print(ordered_regions2[1].label)
dict_test = {}
#dict_test.update({'Well 1':34.232})
#dict_test.update({'Well 2':44.232})
dict_test.update({'Precipitate Area':[34.232,44.34242]})
import pandas as pd
print(dict_test)
df = pd.DataFrame(dict_test,index=['Well 1','Well 2'])
df
# Out:
# 2
# {'Precipitate Area': [34.232, 44.34242]}
#         Precipitate Area
# Well 1          34.23200
# Well 2          44.34242

# %%
plt.figure(figsize=(16,12))
switch_dir('Over')
plt.imshow(mpimg.imread(Over[-1]),cmap='gray')

# %%
plt.figure(figsize=(16,12))
switch_dir('Under')
plt.imshow(mpimg.imread(Under[-1]),cmap='gray')

# %%
beggining_ending = [0,len(Over)-1]
from skimage.measure import label, regionprops
from skimage.morphology import opening, disk
import time
start = time.time()
circle_mean=[]
box_mean=[]
well_list = []
def Find_Precipitate_Features(Under_dir):
    precip = []
    for j,region in enumerate(ordered_regions2):
        region2 = ordered_regions2[j]
        model2.eval()
        Prediction = torch.round(torch.sigmoid(model2(Images[j].unsqueeze(0).permute(0,3,1,2).cuda())))
        if Prediction == 0:
            well_list.append(f'Well {j}')
            precip.append(0)
            continue   
            
        
        def rgb2gray(rgb):
            return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
        switch_dir('Under')
        back = mpimg.imread(Under[-1]).copy()
        # Finding the precipitate 
        Gray_well = rgb2gray(back[region.slice])
        well_num = j
        Gray_well[Gray_well==0] = 255
        smask = opening(Gray_well, disk(5)) # this seems to be needed to remove some noise
        label_image = label(50>smask)
        if len(regionprops(label_image))==0:
            continue
        region_well = regionprops(label_image)
        if len(region_well)>1:
            out = 0
            for i in range(len(region_well)):
                out += region_well[i].area
        else: 
            out = region_well[0].area
        
        well_list.append(f'Well {well_num}')
        precip.append(out)
    
    df_precip_area = pd.DataFrame({'Precipitate Area (pixels)':precip},index=well_list)
    return df_precip_area


df = Find_Precipitate_Features(Under)
print(time.time()-start)
plt.figure(figsize=(16,12))
switch_dir('Under')
mask2 = mpimg.imread(Under[-1])
plt.imshow(mask2)
for n, region in enumerate(ordered_regions2):
    precip = df.iloc[n][0]
    j, i = region.centroid
    if precip > 0:
        plt.plot(i, j, 'bo', ms=3) # we plot these in the opposite order we read them.
        plt.text(i, j-60, f'{precip:.2f}', ha='center',va='bottom',fontweight='bold',c='b')
    else:
        plt.plot(i, j, 'ro', ms=3) # we plot these in the opposite order we read them.
        plt.text(i, j-60, f'No Precip', ha='center',va='bottom',fontweight='bold',c='r')
# Out:
# 2.5842502117156982

# %%
Images = np.zeros((len(ordered_regions2),80,80,3))
switch_dir('Under')
for i,region in enumerate(ordered_regions2):
    X,Y = region.coords[:,0],region.coords[:,1]
    back = mpimg.imread(Under[-1]).copy()[region.slice][:80,:80,:]
    Images[i,:] = back

# %%
Images.shape
# Out:
# (108, 80, 80, 3)

# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 17.5 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=4.1.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torchvision) (7.0.0)
# Requirement already satisfied: numpy in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torchvision) (1.18.1)
# Requirement already satisfied: torch==1.7.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torchvision) (1.7.0)
# Requirement already satisfied: future in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torch==1.7.0->torchvision) (0.18.2)
# Requirement already satisfied: dataclasses in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torch==1.7.0->torchvision) (0.6)
# Requirement already satisfied: typing-extensions in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from torch==1.7.0->torchvision) (3.7.4.3)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.8.1

# %%
import torch
Images = torch.Tensor(Images)

# %%
Wells_with_precip = np.array([23,31,32,33,34,35,43,44,45,46,47,55,56,57,58,59,67,68,69,70,71,79,80,81,82,83,91,92,93,94,95])
Targets = np.array([0 if x not in Wells_with_precip else 1 for x in range(108)])

# %%
Targets[2]
# Out:
# tensor(0.)

# %%
Targets = torch.Tensor(Targets)
Targets.shape
# Out:
# torch.Size([108])

# %%
from __future__ import print_function, division
import os
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

class My_Dataset(Dataset):
    
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
        
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self,index):
        
        X =  self.X[index]
        Y = self.Y[index].long()
        return X,Y

# %%
Dataset_binary_label = My_Dataset(Images,Targets)
dataloader = DataLoader(Dataset_binary_label, batch_size=4,pin_memory=True,
                        shuffle=True, num_workers=6)

# %%
#os.chdir('..')
model2 = Network(3,1).float()
model2.load_state_dict(torch.load('Model_Classification_GPU_430_epochs.pt'));
model2.eval()
device = torch.device("cuda")
model2.to(device)
# Out:
# Network(
#   (layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): Dropout(p=0.3, inplace=False)
#     (14): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (linear_layer_classes): Linear(in_features=204800, out_features=1, bias=False)
# )

# %%
print(Prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-fb45f3c2fa91> in <module>
# ----> 1 print(Prediction)
#
# NameError: name 'Prediction' is not defined

# %%
Images[1].unsqueeze(0).shape
# Out:
# torch.Size([1, 80, 80, 3])

# %%
Images[1].shape
Images[1].reshape((1,80,80,3)).shape
model2.eval()
Prediction = torch.sigmoid(model2(Images[23].unsqueeze(0).permute(0,3,1,2).cuda()))
print(Prediction)
Prediction = torch.round(Prediction)
if Prediction == 0:
    print(f'The model predicts there is not precipitate in this well')
else:
    print(f'The model predicts there is precipitate in this well')
plt.imshow(mpimg.imread(Under[-1]).copy()[ordered_regions2[23].slice])
# Out:
# tensor([[1.]], device='cuda:0', grad_fn=<SigmoidBackward>)
# The model predicts there is precipitate in this well

# %%
#plt.imshow(Images[55].numpy().astype('int'))

# %%
for img, label in dataloader:
    print(img.shape,label.shape)
# Out:
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])
# torch.Size([4, 80, 80, 3]) torch.Size([4])

# %%
import torch
criterion = nn.BCEWithLogitsLoss()
optimizer_model = torch.optim.Adam(Net.parameters(),lr=1e-4)
Net.train()
Losses = []
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_model, mode='min', factor=0.05, patience=10, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08, verbose=True)
for epoch in range(1000):
    
    for batch_num,(img,label) in enumerate(dataloader):
        img,label = img.to(device),label.to(device)
        optimizer_model.zero_grad()
        preds = Net(img.permute(0,3,1,2).float())
        loss = criterion(preds, label.unsqueeze(1).float())
        loss.backward()
        Losses.append(loss.item())
        optimizer_model.step()
        
    if epoch % 10 == 0:
        print(f'\n Epoch: {epoch}, \n Current Loss: {np.mean(Losses)}, \n Current prediction probabilities {torch.sigmoid(preds)} vs actual {label}')
        scheduler.step(np.mean(Losses))
    Losses = []

torch.save(Net.state_dict(), 'Model_Classification2.pt')
# Out:
#  Epoch: 0,
#  Current Loss: 1.0542889006987766,
#  Current prediction probabilities tensor([[0.9998],
#         [0.0897],
#         [0.9997],
#         [0.1402]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 1, 0], device='cuda:0')
#
#  Epoch: 10,
#  Current Loss: 0.0018999926585281544,
#  Current prediction probabilities tensor([[2.4383e-04],
#         [9.9808e-01],
#         [1.5595e-03],
#         [9.8884e-01]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 0, 1], device='cuda:0')
#
#  Epoch: 20,
#  Current Loss: 0.20374856937121,
#  Current prediction probabilities tensor([[9.9999e-01],
#         [1.0023e-05],
#         [5.0808e-06],
#         [2.1043e-05]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 0, 0], device='cuda:0')
#
#  Epoch: 30,
#  Current Loss: 0.014725501373902716,
#  Current prediction probabilities tensor([[6.5870e-05],
#         [5.6113e-08],
#         [2.6728e-05],
#         [5.7239e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 40,
#  Current Loss: 0.00014035205796858463,
#  Current prediction probabilities tensor([[2.6883e-08],
#         [1.2309e-09],
#         [5.0075e-07],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 50,
#  Current Loss: 0.00011913282226579988,
#  Current prediction probabilities tensor([[4.0201e-06],
#         [4.7037e-06],
#         [3.4113e-07],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 60,
#  Current Loss: 2.4159603442428676e-05,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [1.0000e+00],
#         [1.1275e-07],
#         [1.2413e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 1, 0, 0], device='cuda:0')
#
#  Epoch: 70,
#  Current Loss: 4.799692189761663e-05,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [1.0000e+00],
#         [7.2018e-09],
#         [8.8518e-06]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 1, 0, 0], device='cuda:0')
#
#  Epoch: 80,
#  Current Loss: 1.788680235116481e-05,
#  Current prediction probabilities tensor([[8.3316e-07],
#         [5.3130e-06],
#         [8.8383e-07],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 90,
#  Current Loss: 2.0928747260792642e-05,
#  Current prediction probabilities tensor([[2.3202e-04],
#         [3.8143e-05],
#         [1.4879e-06],
#         [9.9999e-01]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 100,
#  Current Loss: 1.2342846328084323e-05,
#  Current prediction probabilities tensor([[1.4313e-06],
#         [5.2481e-09],
#         [4.7464e-08],
#         [3.8885e-06]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 110,
#  Current Loss: 1.1792580323273157e-05,
#  Current prediction probabilities tensor([[3.1558e-07],
#         [1.1641e-05],
#         [9.1064e-13],
#         [1.4367e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 120,
#  Current Loss: 8.20631013105284e-06,
#  Current prediction probabilities tensor([[3.1498e-07],
#         [7.3796e-09],
#         [3.5515e-08],
#         [2.7182e-08]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 130,
#  Current Loss: 8.981446638527072e-06,
#  Current prediction probabilities tensor([[9.3182e-08],
#         [1.5562e-09],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 1], device='cuda:0')
#
#  Epoch: 140,
#  Current Loss: 5.788039715597464e-06,
#  Current prediction probabilities tensor([[9.1811e-07],
#         [7.7587e-09],
#         [5.6091e-07],
#         [1.6151e-08]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 150,
#  Current Loss: 8.229249605767669e-06,
#  Current prediction probabilities tensor([[1.3736e-10],
#         [2.7100e-06],
#         [1.0000e+00],
#         [1.1893e-08]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
#
#  Epoch: 160,
#  Current Loss: 5.307875255635121e-06,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [2.0283e-06],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 1, 1], device='cuda:0')
#
#  Epoch: 170,
#  Current Loss: 1.1299295139971727e-05,
#  Current prediction probabilities tensor([[1.3461e-08],
#         [2.5852e-07],
#         [1.0000e+00],
#         [3.5152e-05]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
#
#  Epoch: 180,
#  Current Loss: 7.423505473348592e-06,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [3.2458e-08],
#         [1.8295e-08],
#         [8.0482e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 0, 0], device='cuda:0')
#
#  Epoch: 190,
#  Current Loss: 8.763116134628771e-06,
#  Current prediction probabilities tensor([[7.4158e-07],
#         [3.1129e-06],
#         [1.0000e+00],
#         [1.2453e-06]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
#
#  Epoch: 200,
#  Current Loss: 2.1068859565234436e-05,
#  Current prediction probabilities tensor([[9.9997e-01],
#         [1.0000e+00],
#         [1.4085e-07],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 1, 0, 1], device='cuda:0')
#
#  Epoch: 210,
#  Current Loss: 6.0390104622874853e-05,
#  Current prediction probabilities tensor([[3.2087e-06],
#         [1.7636e-09],
#         [1.0000e+00],
#         [3.6152e-06]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
#
#  Epoch: 220,
#  Current Loss: 4.640077152268313e-06,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [1.1183e-10],
#         [1.0000e+00],
#         [6.7452e-06]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 1, 0], device='cuda:0')
#
#  Epoch: 230,
#  Current Loss: 3.2836572053045957e-06,
#  Current prediction probabilities tensor([[1.1538e-06],
#         [1.7950e-09],
#         [2.2070e-06],
#         [3.3662e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 240,
#  Current Loss: 2.144594522182733e-06,
#  Current prediction probabilities tensor([[8.8207e-09],
#         [1.6301e-08],
#         [3.7921e-05],
#         [1.5504e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 250,
#  Current Loss: 8.521203113655542e-07,
#  Current prediction probabilities tensor([[1.1328e-07],
#         [3.1352e-08],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 1], device='cuda:0')
#
#  Epoch: 260,
#  Current Loss: 1.413933137486525e-06,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [1.1131e-06],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 1, 1], device='cuda:0')
#
#  Epoch: 270,
#  Current Loss: 8.238675901620188e-05,
#  Current prediction probabilities tensor([[2.7992e-06],
#         [6.9598e-08],
#         [1.4235e-06],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 280,
#  Current Loss: 0.00044901453803598883,
#  Current prediction probabilities tensor([[5.0871e-21],
#         [1.0000e+00],
#         [9.9999e-01],
#         [1.1996e-03]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 1, 0], device='cuda:0')
#
#  Epoch: 290,
#  Current Loss: 0.00020644398500893304,
#  Current prediction probabilities tensor([[5.8911e-04],
#         [2.5185e-07],
#         [1.0626e-20],
#         [9.9999e-01]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 300,
#  Current Loss: 7.6177089704709e-05,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [2.3692e-04],
#         [9.1329e-07],
#         [3.0622e-07]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 0, 0], device='cuda:0')
#
#  Epoch: 310,
#  Current Loss: 5.65568998411376e-05,
#  Current prediction probabilities tensor([[3.6081e-06],
#         [3.1323e-04],
#         [1.0000e+00],
#         [1.0325e-13]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
#
#  Epoch: 320,
#  Current Loss: 4.2001134624788015e-05,
#  Current prediction probabilities tensor([[1.5071e-09],
#         [1.8495e-04],
#         [2.4375e-15],
#         [1.1132e-14]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 330,
#  Current Loss: 4.8203614457770424e-05,
#  Current prediction probabilities tensor([[8.2497e-07],
#         [1.0000e+00],
#         [2.8215e-13],
#         [4.0375e-08]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 0, 0], device='cuda:0')
#
#  Epoch: 340,
#  Current Loss: 2.3166053883753818e-05,
#  Current prediction probabilities tensor([[2.3856e-05],
#         [1.6629e-08],
#         [2.7183e-14],
#         [4.6796e-10]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 0], device='cuda:0')
#
#  Epoch: 350,
#  Current Loss: 2.8650949897276497e-05,
#  Current prediction probabilities tensor([[5.7483e-05],
#         [1.0000e+00],
#         [2.7941e-15],
#         [1.6778e-09]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 0, 0], device='cuda:0')
#
#  Epoch: 360,
#  Current Loss: 1.5025808126557228e-05,
#  Current prediction probabilities tensor([[1.8475e-12],
#         [1.0098e-05],
#         [1.0000e+00],
#         [1.2436e-13]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
# Epoch    37: reducing learning rate of group 0 to 5.0000e-06.
#
#  Epoch: 370,
#  Current Loss: 1.6805877283719315e-05,
#  Current prediction probabilities tensor([[6.3162e-07],
#         [1.0000e+00],
#         [1.0000e+00],
#         [9.8526e-12]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 1, 0], device='cuda:0')
#
#  Epoch: 380,
#  Current Loss: 1.7746705766428392e-05,
#  Current prediction probabilities tensor([[1.1184e-07],
#         [3.8741e-22],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 1], device='cuda:0')
#
#  Epoch: 390,
#  Current Loss: 2.906235372732466e-05,
#  Current prediction probabilities tensor([[2.9411e-14],
#         [7.2650e-15],
#         [1.4052e-04],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 0, 1], device='cuda:0')
#
#  Epoch: 400,
#  Current Loss: 8.88571470045647e-05,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [1.0000e+00],
#         [3.7955e-08],
#         [4.3432e-10]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 1, 0, 0], device='cuda:0')
#
#  Epoch: 410,
#  Current Loss: 1.293336698412925e-05,
#  Current prediction probabilities tensor([[9.8373e-14],
#         [1.0000e+00],
#         [1.0000e+00],
#         [1.0000e+00]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 1, 1, 1], device='cuda:0')
#
#  Epoch: 420,
#  Current Loss: 1.1813305359380192e-05,
#  Current prediction probabilities tensor([[1.0000e+00],
#         [3.4557e-18],
#         [1.6105e-11],
#         [2.6281e-05]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([1, 0, 0, 0], device='cuda:0')
#
#  Epoch: 430,
#  Current Loss: 1.4250044731635694e-05,
#  Current prediction probabilities tensor([[1.0001e-09],
#         [7.4704e-05],
#         [1.0000e+00],
#         [1.2097e-13]], device='cuda:0', grad_fn=<SigmoidBackward>) vs actual tensor([0, 0, 1, 0], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-afb450fe0038> in <module>
#      11         optimizer_model.zero_grad()
#      12         preds = Net(img.permute(0,3,1,2).float())
# ---> 13         loss = criterion(preds, label.unsqueeze(1).float())
#      14         loss.backward()
#      15         Losses.append(loss.item())
#
# KeyboardInterrupt:

# %%
torch.save(Net.state_dict(), 'Model_Classification_GPU_430_epochs.pt')
#files.download(f'Model_V2_Epoch_{epoch}.pt')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import torchvision
import torch.nn as nn
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Net = nn.Sequential(torchvision.models.squeezenet1_1(pretrained=False, progress=True),
#                     nn.Linear(1000,1,bias=False))
Net = Network(3,1)
Net.to(device)
Net = Net.float()

# %%
Model_type = 'Baseline'
import torch.nn as nn
class Normal_Block(nn.Module):
  def __init__(self, in_channels, out_channels):
        super(Normal_Block, self).__init__()

        self.block1 = nn.Sequential(nn.Conv2d(in_channels=in_channels,out_channels=out_channels,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels=out_channels,out_channels=out_channels,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU())
            #nn.Conv2d(in_channels=out_channels,out_channels=out_channels,kernel_size = 3,stride=1,padding=1,bias=False),
            #nn.BatchNorm2d(out_channels),
            #nn.ReLU())
        
        self.shortcut = nn.Sequential( 
            nn.Conv2d(in_channels=in_channels,out_channels=out_channels,kernel_size=3,stride =1, padding=1,bias=False),
            nn.BatchNorm2d(out_channels),
                                )
        
  def forward(self, x):
      output = self.block1(x)
      res = self.shortcut(x)
      output += res # self.shortcut(x)
      return output

class Network(nn.Module): # [3,4,6,3] first resNet use block 3 times then the second use it 4 times
    def __init__(self, num_feats, num_classes):
        super(Network, self).__init__()
        
        self.layers = nn.Sequential(
            nn.Conv2d(in_channels=num_feats,out_channels=64,kernel_size = 7,stride=2,padding=3,bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(in_channels=64,out_channels=64,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(in_channels=64,out_channels=64,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(in_channels=64,out_channels=128,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(in_channels=128,out_channels=128,kernel_size = 3,stride=1,padding=1,bias=False),
            nn.BatchNorm2d(128),
                                    )

        # LINEAR LAYER (For Classes)
        self.linear_layer_classes = nn.Linear(204800,num_classes,bias=False)


    def forward(self, x, evalMode=False):
        # Baseline layers 
        output = self.layers(x)
        output = output.reshape(output.shape[0],-1)
        label_output = self.linear_layer_classes(output)
        label_output = label_output/torch.norm(self.linear_layer_classes.weight, dim=1)
        
        return label_output

# %%
Net = Network(3,1).float()
Net
# Out:
# Network(
#   (layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): Dropout(p=0.3, inplace=False)
#     (14): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (linear_layer_classes): Linear(in_features=204800, out_features=1, bias=False)
# )

# %%
df[df['Precipitate Area (pixels)']>0]
# Out:
#          Precipitate Area (pixels)
# Well 4                         856
# Well 24                        572
# Well 32                        112
# Well 33                        215
# Well 35                         18
# Well 44                       1023
# Well 46                       1101
# Well 47                       1418
# Well 55                       1306
# Well 56                       1505
# Well 58                       1697
# Well 67                       1522
# Well 68                       1570
# Well 69                       1583
# Well 70                       1696
# Well 71                       2092
# Well 79                       1738
# Well 80                       1608
# Well 81                       1399
# Well 82                       1878
# Well 83                       1805
# Well 91                       2301
# Well 92                       1986
# Well 93                       2181
# Well 94                       2334
# Well 95                       1630

# %%
import numpy as np

switch_dir('Under')
back = mpimg.imread(Under[-1]).copy()
#image3 = back.copy() # Copying the original image of the plate

mask2 = np.ones(shape=back.shape[0:2], dtype="bool") # create the mask image
R = 56 - 15 # Radius of circles
i = 1

for coor in centers_back:
    x = int(coor[0])
    y = int(coor[1])
    rr, cc = skimage.draw.circle(y, x, radius=R, shape=back.shape[0:2])
    i = 2
    mask2[rr, cc] = False

# Apply the mask
back[mask2] = 0

    
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
#switch_dir('Under')
#back = mpimg.imread(Under[-1]).copy()
region = ordered_regions2[34]

Gray_well = rgb2gray(back[region.slice])
plt.imshow(Gray_well,cmap='gray')
well_num = 34
Gray_well[Gray_well==0] = 255#
smask = opening(Gray_well, disk(5)) # this seems to be needed to remove some noise
label_image = label(50>smask)
#print(regionprops(label_image))
print(len(regionprops(label_image)))
#Darkness_changes[j] < 0.02:
region = regionprops(label_image)[1]
print(f'The area of the precipitate for well {well_num} is {region.area} pixels, len {len(regionprops(label_image))}')
#Gray_well = rgb2gray(pixels)
#plt.imshow(Gray_well,cmap='gray')
# Out:
# 5
# The area of the precipitate for well 34 is 47 pixels, len 5

# %% [markdown]
# **I keep forgetting that when slicing a array for an image its "array[y_slice,x_slice]" not x then y**

# %%
from datetime import datetime
import glob
import os
import operator

image_files = glob.glob('PtcolZnrow/images/*A_y*.jpg')

dates = [datetime.strptime(os.path.split(f)[-1],
                           f'PtcolZnrowA_y%ym%md%dH%HM%MS%S.jpg')
         for f in image_files]

# This is a sorted list of tuples (filename, datetime) for each image
images = [x[0] for x in sorted(zip(image_files, dates), key=operator.itemgetter(1))]

# %%
import time
import numpy as np 

t0 = time.time()
all_data = []

for imf in images:
    rimg = rgb2gray(mpimg.imread(imf))
    data = []
    for region in ordered_regions:
        minr, minc, maxr, maxc = region.bbox
        pixels = rimg[minr:maxr, minc:maxc][region.image] # this is where we get the circular region
        data += [[np.mean(pixels), np.median(pixels), np.max(pixels)]]
    all_data += [np.array(data)]

all_data = np.array(all_data)
print(f'Elapsed time = {time.time() - t0}')
all_data.shape
# Out:
# Elapsed time = 0.00021910667419433594
# (0,)

# %%
nd = all_data[:, :, 0]
nd.shape
nd /= nd[0, :]
plt.plot(nd);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-7d515d58be5c> in <module>
# ----> 1 nd = all_data[:, :, 0]
#       2 nd.shape
#       3 nd /= nd[0, :]
#       4 plt.plot(nd);
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed

# %% [markdown]
# **Now I am putting the data into a pandas dataframe**

# %%
import pandas as pd
wellnum = 1
time = [i+1 for i in range(len(nd[:,0]))] * 108
df2 = pd.DataFrame()
df2[('Time_Step')] = time
H2 = []
Well_Number = []
for col in range(108):
    H2.append(nd[:,col])
    wellnum = wellnum + 1
    Well_Number.append(['Well ' + str(col + 1)]*104)
H2 = np.reshape(H2,108*104)
Well_Number = np.reshape(Well_Number,108*104)
df2[('Hydrogen')] = H2
df2[('Well')] = Well_Number
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9455b2ac7416> in <module>
#      10     wellnum = wellnum + 1
#      11     Well_Number.append(['Well ' + str(col + 1)]*104)
# ---> 12 H2 = np.reshape(H2,108*104)
#      13 Well_Number = np.reshape(Well_Number,108*104)
#      14 df2[('Hydrogen')] = H2
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# ValueError: cannot reshape array of size 11124 into shape (11232,)

# %% [markdown]
# **Using the dataframe I am making subplots (box and whisker and scatter) for each row**

# %%
import seaborn as sns
f, axes = plt.subplots(9, 2, sharey=True, figsize=(30, 46))
for i in range(9):
    sns.boxplot(x="Well", y="Hydrogen", data=df2[i*104*12:(i+1)*104*12], ax=axes[i,0])
    sns.scatterplot(x="Time_Step", y="Hydrogen", hue="Well", data=df2[i*104*12:(i+1)*104*12], ax=axes[i,1]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e128eab8a961> in <module>
#       2 f, axes = plt.subplots(9, 2, sharey=True, figsize=(30, 46))
#       3 for i in range(9):
# ----> 4     sns.boxplot(x="Well", y="Hydrogen", data=df2[i*104*12:(i+1)*104*12], ax=axes[i,0])
#       5     sns.scatterplot(x="Time_Step", y="Hydrogen", hue="Well", data=df2[i*104*12:(i+1)*104*12], ax=axes[i,1]);
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **This second dataframe is just seperated by well number for the remaining plots**

# %%
wellnum =1
time = [i+1 for i in range(len(nd[:,0]))]
picdata = pd.DataFrame()
picdata[('Time_Step')] = time
for col in range(108):
    picdata[('Well'+str(wellnum))]=nd[:,col]
    wellnum = wellnum+1
picdata

# %%
sns.catplot(x="Time_Step", y="Well1", data=picdata);

# %%
f,axis = plt.subplots(9,8,figsize=(40,40))
WELL_NUM = 1
for i in range(9):
    for j in range(8):
        bigpic = sns.scatterplot(data=picdata,x='Time_Step',y=('Well'+str(WELL_NUM)),ax = axis[i,j],alpha = .6)
        WELL_NUM += 1

# %%
import json

with open('PtcolZnrow/output/wholeplatedat.JSON') as f:
    d = json.loads(f.read())

# %%
import numpy as np 
import matplotlib.pyplot as plt
d

# %%
eric_nd = np.array([x['Normalized Darkness'] for x in d])

# %%
f,ax = plt.subplots(1,2)
ax[0].plot(eric_nd.T);
ax[1].plot(nd);
